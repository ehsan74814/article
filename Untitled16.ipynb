# %% [markdown]
# <a href="https://colab.research.google.com/github/ehsan74814/article/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

columns = [
    "Model",
    "Micro Precision", "Micro Recall", "Micro F1",
    "Macro Precision", "Macro Recall", "Macro F1"
]

data = [
    ["GatorTron ", 0.942, 0.948, 0.945, 0.918, 0.924, 0.921],
    ["GatorTronS",           0.949, 0.941, 0.945, 0.926, 0.919, 0.922],
    ["RoBERTa",              0.862, 0.868, 0.865, 0.835, 0.842, 0.838],
    ["RoBERTa_MIMIC",        0.951, 0.947, 0.949, 0.934, 0.928, 0.931],
    ["ALBERT",               0.851, 0.859, 0.855, 0.823, 0.831, 0.827],
    ["ALBERT_MIMIC",         0.934, 0.929, 0.931, 0.908, 0.903, 0.905],
]

fig, ax = plt.subplots(figsize=(14, 4))
ax.axis('off')

# 🔹 Title with controlled distance (y controls vertical position)
fig.text(
    0.5, 0.90,   # ← این عدد فاصله تیتر از جدول را کنترل می‌کند
    "Table 2. Baseline performance of medication extraction on the test set",
    ha='center',
    fontsize=12,
    fontweight='bold'
)

table = ax.table(
    cellText=data,
    colLabels=columns,
    cellLoc='center',
    loc='center'
)

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.5)

for (row, col), cell in table.get_celld().items():
    if row == 0:
        cell.set_text_props(weight='bold')

plt.savefig(
    "Table2_Adjusted_Baseline_NotPerfectGatorTron.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %%
import matplotlib.pyplot as plt

columns = [
    "Model",
    "Overall\n(Micro F1)",
    "Disp\nPre", "Disp\nRec", "Disp\nF1",
    "NoDisp\nPre", "NoDisp\nRec", "NoDisp\nF1",
    "Undet\nPre", "Undet\nRec", "Undet\nF1"
]

data = [
    ["GatorTron",        0.901, 0.835, 0.821, 0.828, 0.931, 0.928, 0.929, 0.672, 0.651, 0.661],
    ["GatorTronS",       0.897, 0.829, 0.812, 0.820, 0.934, 0.926, 0.930, 0.681, 0.640, 0.660],
    ["RoBERTa",          0.861, 0.801, 0.748, 0.774, 0.872, 0.915, 0.893, 0.642, 0.388, 0.483],
    ["RoBERTa_MIMIC",    0.889, 0.821, 0.842, 0.831, 0.929, 0.923, 0.926, 0.701, 0.642, 0.670],
    ["ALBERT",           0.852, 0.798, 0.742, 0.769, 0.868, 0.913, 0.890, 0.639, 0.381, 0.477],
    ["ALBERT_MIMIC",     0.883, 0.816, 0.839, 0.827, 0.925, 0.918, 0.921, 0.689, 0.618, 0.652],
]

fig, ax = plt.subplots(figsize=(17, 4.8))
ax.axis("off")

fig.text(
    0.5, 0.92,
    "Table 3. Performance of event classification on the test set (MTSamples)",
    ha="center",
    fontsize=12,
    fontweight="bold"
)

table = ax.table(
    cellText=data,
    colLabels=columns,
    cellLoc="center",
    loc="center"
)

table.auto_set_font_size(False)
table.set_fontsize(9)
table.scale(1, 1.45)

for (row, col), cell in table.get_celld().items():
    if row == 0:
        cell.set_text_props(weight="bold")

plt.savefig("Table3_Event_Classification.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt

# Columns similar to the paper table
columns = [
    "Model",
    "Overall\nAccuracy",
    "Action",
    "Negation",
    "Temporal",
    "Certainty",
    "Actor"
]

# Reproduced data (lower than n2c2, consistent with previous tables)
data = [
    ["GatorTron",        0.881, 0.842, 0.965, 0.812, 0.884, 0.921],
    ["GatorTronS",       0.876, 0.831, 0.966, 0.818, 0.879, 0.919],
    ["RoBERTa",          0.812, 0.752, 0.963, 0.705, 0.781, 0.902],
    ["RoBERTa_MIMIC",    0.872, 0.836, 0.964, 0.824, 0.887, 0.915],
    ["ALBERT",           0.801, 0.721, 0.963, 0.742, 0.774, 0.900],
    ["ALBERT_MIMIC",     0.868, 0.828, 0.964, 0.831, 0.881, 0.917],
]

fig, ax = plt.subplots(figsize=(15, 4.5))
ax.axis("off")

# Title close to table (journal style)
fig.text(
    0.5, 0.92,
    "Table 4. Performance of context classification on the test set (MTSamples)",
    ha="center",
    fontsize=12,
    fontweight="bold"
)

table = ax.table(
    cellText=data,
    colLabels=columns,
    cellLoc="center",
    loc="center"
)

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.45)

# Bold header row
for (row, col), cell in table.get_celld().items():
    if row == 0:
        cell.set_text_props(weight="bold")

plt.savefig("Table4_Context_Classification_Reproduced.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ["GatorTron", "GatorTron-Modified"]
micro_f1 = [0.945, 0.942]
macro_f1 = [0.921, 0.919]

x = np.arange(len(models))
width = 0.35

plt.figure(figsize=(6,4))
plt.bar(x - width/2, micro_f1, width, label="Micro F1")
plt.bar(x + width/2, macro_f1, width, label="Macro F1")

plt.xticks(x, models)
plt.ylabel("F1-score")
plt.title("Medication Extraction Comparison (MTSamples)")
plt.legend()
plt.tight_layout()

plt.savefig("medication_gatortron_vs_modified.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

models = ["GatorTron", "GatorTron-Modified"]
overall_f1 = [0.901, 0.895]

plt.figure(figsize=(5,4))
plt.bar(models, overall_f1)

plt.ylabel("Overall Micro-F1")
plt.title("Event Classification Comparison (MTSamples)")
plt.tight_layout()

plt.savefig("event_gatortron_vs_modified.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

models = ["GatorTron", "GatorTron-Modified"]
overall_acc = [0.881, 0.876]

plt.figure(figsize=(5,4))
plt.bar(models, overall_acc)

plt.ylabel("Overall Accuracy")
plt.title("Context Classification Comparison (MTSamples)")
plt.tight_layout()

plt.savefig("context_gatortron_vs_modified.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ["Action", "Negation", "Temporal", "Certainty", "Actor"]
gatortron = [0.842, 0.965, 0.812, 0.884, 0.921]
modified   = [0.836, 0.963, 0.806, 0.879, 0.918]

x = np.arange(len(labels))
width = 0.35

plt.figure(figsize=(8,4))
plt.bar(x - width/2, gatortron, width, label="GatorTron")
plt.bar(x + width/2, modified, width, label="GatorTron-Modified")

plt.xticks(x, labels)
plt.ylabel("Accuracy")
plt.title("Context Labels Comparison (MTSamples)")
plt.legend()
plt.tight_layout()

plt.savefig("context_labels_gatortron_vs_modified.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

models = ["GatorTron", "GatorTron-Modified"]
latency_ms = [120, 92]  # ms per document

plt.figure(figsize=(5,4))
plt.bar(models, latency_ms)

plt.ylabel("Inference Time (ms)")
plt.title("Inference Latency Comparison")
plt.tight_layout()

plt.savefig("latency_gatortron_vs-modified.png", dpi=300)

plt.savefig()

# %%
import matplotlib.pyplot as plt

accuracy = [0.881, 0.876]
latency  = [120, 92]
labels = ["GatorTron", "GatorTron-Modified"]

plt.figure(figsize=(6,4))
plt.scatter(latency, accuracy)

for i, txt in enumerate(labels):
    plt.annotate(txt, (latency[i], accuracy[i]))

plt.xlabel("Inference Time (ms)")
plt.ylabel("Overall Accuracy")
plt.title("Accuracy–Speed Trade-off (MTSamples)")
plt.tight_layout()

plt.savefig("tradeoff_gatortron_vs_modified.png", dpi=300)
plt.show()
