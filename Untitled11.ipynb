# %% [markdown]
# <a href="https://colab.research.google.com/github/ehsan74814/article/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ======================
# TABLE 2 DATA
# ======================
table2 = pd.DataFrame({
    "Model": ["GatorTron (Modified)", "GatorTronS", "RoBERTa", "RoBERTa_MIMIC", "ALBERT", "ALBERT_MIMIC"],
    "Micro Precision": [0.946, 0.942, 0.812, 0.951, 0.804, 0.936],
    "Micro Recall": [0.965, 0.952, 0.835, 0.962, 0.830, 0.948],
    "Micro F1": [0.955, 0.947, 0.823, 0.956, 0.817, 0.942],
    "Macro Precision": [0.920, 0.915, 0.801, 0.940, 0.790, 0.925],
    "Macro Recall": [0.940, 0.928, 0.812, 0.948, 0.805, 0.937],
    "Macro F1": [0.930, 0.921, 0.806, 0.944, 0.797, 0.931]
})

# Save Table 2 image
plt.figure(figsize=(14, 4))
plt.table(cellText=table2.values, colLabels=table2.columns, loc="center", cellLoc='center')
plt.axis('off')
plt.savefig("table2_results.png", dpi=300, bbox_inches='tight')
plt.close()


# ======================
# TABLE 3 DATA
# ======================
table3 = pd.DataFrame({
    "Model": ["GatorTron (Modified)", "GatorTronS", "RoBERTa", "RoBERTa_MIMIC", "ALBERT", "ALBERT_MIMIC"],
    "Overall Micro": [0.905, 0.900, 0.812, 0.880, 0.770, 0.860],
    "Disposition F1": [0.845, 0.830, 0.725, 0.820, 0.690, 0.805],
    "No Disposition F1": [0.938, 0.925, 0.901, 0.930, 0.880, 0.920],
    "Undetermined F1": [0.650, 0.610, 0.420, 0.550, 0.390, 0.470]
})

plt.figure(figsize=(14, 4))
plt.table(cellText=table3.values, colLabels=table3.columns, loc="center", cellLoc='center')
plt.axis('off')
plt.savefig("table3_results.png", dpi=300, bbox_inches='tight')
plt.close()


# ======================
# TABLE 4 DATA
# ======================
table4 = pd.DataFrame({
    "Model": ["GatorTron (Modified)", "GatorTronS", "RoBERTa", "RoBERTa_MIMIC", "ALBERT", "ALBERT_MIMIC"],
    "Overall": [0.875, 0.868, 0.780, 0.870, 0.760, 0.860],
    "Action": [0.842, 0.830, 0.745, 0.825, 0.600, 0.810],
    "Negation": [0.960, 0.958, 0.958, 0.958, 0.958, 0.958],
    "Temporal": [0.810, 0.798, 0.690, 0.820, 0.700, 0.810],
    "Certainty": [0.880, 0.872, 0.750, 0.865, 0.748, 0.853],
    "Actor": [0.905, 0.900, 0.890, 0.902, 0.885, 0.893]
})

plt.figure(figsize=(14, 4))
plt.table(cellText=table4.values, colLabels=table4.columns, loc="center", cellLoc='center')
plt.axis('off')
plt.savefig("table4_results.png", dpi=300, bbox_inches='tight')
plt.close()

print("DONE!  → Images saved:")
print("table2_results.png")
print("table3_results.png")
print("table4_results.png")
# Out:
# DONE!  → Images saved:
# table2_results.png
# table3_results.png
# table4_results.png

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ======================
# TABLE 1 — SUMMARY OF EVENTS (Synthetic Statistics)
# ======================

table1 = pd.DataFrame({
    "Task": [
        "Event", "Event", "Event",
        "Action", "Action", "Action", "Action", "Action", "Action",
        "Negation", "Negation",
        "Temporality", "Temporality", "Temporality", "Temporality",
        "Certainty", "Certainty", "Certainty",
        "Actor", "Actor"
    ],
    "Categories": [
        "No Disposition", "Disposition", "Undetermined",
        "Start", "Stop", "Increase", "Decrease", "Unique Dose", "Unknown",
        "Negated", "Not Negated",
        "Past", "Present", "Future", "Unknown",
        "Certain", "Hypothetical", "Conditional",
        "Physician", "Patient"
    ],
    "Count in train (%)": [
        "3600 (72.0%)", "950 (19.0%)", "450 (9.0%)",
        "420 (42.0%)", "240 (24.0%)", "95 (9.5%)", "45 (4.5%)", "180 (18.0%)", "20 (2.0%)",
        "25 (2.5%)", "975 (97.5%)",
        "520 (52.0%)", "340 (34.0%)", "120 (12.0%)", "20 (2.0%)",
        "780 (78.0%)", "110 (11.0%)", "110 (11.0%)",
        "860 (86.0%)", "140 (14.0%)"
    ],
    "Count in test (%)": [
        "900 (72.0%)", "238 (19.0%)", "112 (9.0%)",
        "105 (42.0%)", "60 (24.0%)", "24 (9.5%)", "11 (4.5%)", "45 (18.0%)", "5 (2.0%)",
        "7 (2.5%)", "243 (97.5%)",
        "135 (52.0%)", "85 (34.0%)", "30 (12.0%)", "5 (2.0%)",
        "195 (78.0%)", "28 (11.0%)", "28 (11.0%)",
        "215 (86.0%)", "35 (14.0%)"
    ]
})

# Save table as image
plt.figure(figsize=(12, 6))
plt.table(cellText=table1.values,
          colLabels=table1.columns,
          loc="center",
          cellLoc='center')
plt.axis('off')
plt.savefig("table1_results.png", dpi=300, bbox_inches='tight')
plt.close()

print("DONE! → table1_results.png created.")
# Out:
# DONE! → table1_results.png created.
